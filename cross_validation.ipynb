# %%
import pandas as pd

# %%
df = pd.read_csv('Train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age']= df['Age'].fillna(30)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.758889    0.523008
# std     257.353842    0.486592    0.836071   13.002570    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   30.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
x = df.drop(['PassengerId','Survived','Name','Ticket','Cabin'],axis = 1)
x.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  22.0      1      0   7.2500        S
# 1       1  female  38.0      1      0  71.2833        C
# 2       3  female  26.0      0      0   7.9250        S
# 3       1  female  35.0      1      0  53.1000        S
# 4       3    male  35.0      0      0   8.0500        S

# %%
y = df.Survived

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dfle = x
dfle['Sex'] = le.fit_transform(dfle['Sex'])
dfle
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0         3    1  22.0      1      0   7.2500        S
# 1         1    0  38.0      1      0  71.2833        C
# 2         3    0  26.0      0      0   7.9250        S
# 3         1    0  35.0      1      0  53.1000        S
# 4         3    1  35.0      0      0   8.0500        S
# ..      ...  ...   ...    ...    ...      ...      ...
# 886       2    1  27.0      0      0  13.0000        S
# 887       1    0  19.0      0      0  30.0000        S
# 888       3    0  30.0      1      2  23.4500        S
# 889       1    1  26.0      0      0  30.0000        C
# 890       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %%
dfle['Embarked'] = le.fit_transform(dfle['Embarked'])
dfle
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         3    1  22.0      1      0   7.2500         2
# 1         1    0  38.0      1      0  71.2833         0
# 2         3    0  26.0      0      0   7.9250         2
# 3         1    0  35.0      1      0  53.1000         2
# 4         3    1  35.0      0      0   8.0500         2
# ..      ...  ...   ...    ...    ...      ...       ...
# 886       2    1  27.0      0      0  13.0000         2
# 887       1    0  19.0      0      0  30.0000         2
# 888       3    0  30.0      1      2  23.4500         2
# 889       1    1  26.0      0      0  30.0000         0
# 890       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 7 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dfle,y,test_size=0.3)

# %%
lr = LogisticRegression(solver='liblinear',multi_class='ovr')
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.7574626865671642

# %%
svm = SVC(gamma='auto')
svm.fit(X_train, y_train)
svm.score(X_test, y_test)
# Out:
# 0.6417910447761194

# %%
rf = RandomForestClassifier(n_estimators=40)
rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.7723880597014925

# %%
from sklearn.model_selection import cross_val_score

# %%
lrc=cross_val_score(LogisticRegression(solver='liblinear',multi_class='ovr'), dfle,y,cv=10)

# %%
svc=cross_val_score(SVC(gamma='auto'), dfle,y,cv=10)

# %%
rfv=cross_val_score(RandomForestClassifier(n_estimators=10),dfle,y,cv=10)

# %%
np.mean(lrc)
# Out:
# 0.7946192259675406

# %%
np.mean(svc)
# Out:
# 0.7014856429463171

# %%
np.mean(rfv)
# Out:
# 0.8036204744069912
